# %%
#!/usr/bin/env python
import os
import re
from datetime import datetime
import numpy as np
import torch
import torch.nn as nn
import snntorch as snn
import matplotlib.pyplot as plt
import optuna
from mpl_toolkits.mplot3d import Axes3D  # required for 3D plotting
from torch.utils.tensorboard import SummaryWriter

# =============================================================================
# 1. Fix Random Seeds for Reproducibility
# =============================================================================
np.random.seed(42)
torch.manual_seed(42)

# =============================================================================
# 2. Define Helper Function to Create a Unique Output Folder
# =============================================================================
def create_unique_folder(base_dir):
    """
    Creates a unique folder inside base_dir with the naming pattern:
      trial_N_date_yyyy_mm_dd_hh_mm,
    where N is the highest number found among folders starting with "trial_" plus one.
    """
    if not os.path.exists(base_dir):
        os.makedirs(base_dir)
    # List folders in base_dir that start with "trial_"
    existing = [d for d in os.listdir(base_dir)
                if os.path.isdir(os.path.join(base_dir, d)) and d.startswith("trial_")]
    trial_numbers = []
    for folder in existing:
        match = re.match(r"trial_(\d+)_date_", folder)
        if match:
            trial_numbers.append(int(match.group(1)))
    next_trial = max(trial_numbers) + 1 if trial_numbers else 1
    now_str = datetime.now().strftime("%Y_%m_%d_%H_%M")
    folder_name = f"trial_{next_trial}_date_{now_str}"
    unique_folder = os.path.join(base_dir, folder_name)
    os.makedirs(unique_folder, exist_ok=True)
    return unique_folder

# =============================================================================
# 3. Generate Synthetic Input Signal and Plot It
# =============================================================================
def generate_synthetic_input(output_folder):
    """
    Generates a 1D synthetic signal of 1000 time steps where each block of 100
    time steps alternates between 0.5 and 0.0.
    
    Saves a plot of the input signal inside output_folder.
    
    Returns:
        Tensor of shape (1, 1000, 1)
    """
    num_steps = 1000
    data = np.empty(num_steps, dtype=np.float32)
    for i in range(num_steps):
        data[i] = 1.0 if i == 1 else 0.0
    
    plt.figure(figsize=(8, 4))
    plt.plot(data, marker='o', linestyle='-')
    plt.title('Synthetic Input Signal')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(output_folder, 'synthetic_input.png'))
    plt.close()
    
    # Return tensor with batch dimension and feature dimension
    return torch.tensor(data).unsqueeze(0).unsqueeze(-1)

# =============================================================================
# 4. Define the Spiking Reservoir Experiment Model
# =============================================================================
class SpikingReservoirExp(nn.Module):
    def __init__(self, threshold, beta_reservoir, reservoir_size, device='cpu'):
        """
        Args:
            threshold (float): Threshold (membrane potential) for reservoir LIF neurons.
            beta_reservoir (float): β value for reservoir LIF neurons.
            reservoir_size (int): Number of reservoir neurons (default: 10).
            device (str): 'cpu' or 'cuda'
        """
        super(SpikingReservoirExp, self).__init__()
        self.device = device
        self.reservoir_size = reservoir_size
        
        # Input layer: one linear neuron mapping 1 input to 1.
        self.input_fc = nn.Linear(1, 1, bias=False)
        # Input LIF neuron (fixed parameters; not tuned here).
        self.input_lif = snn.Leaky(beta=0.9,
                                   threshold=1.0,
                                   spike_grad=None,
                                   reset_mechanism='zero',
                                   reset_delay=False)
        
        # Reservoir: a linear mapping from 1 to reservoir_size.
        self.reservoir_fc = nn.Linear(1, reservoir_size, bias=False)
        # Reservoir LIF layer with hyperparameters to be tuned.
        self.reservoir_lif = snn.RLeaky(beta=beta_reservoir,
                                        linear_features=reservoir_size,
                                        threshold=threshold,
                                        spike_grad=None,
                                        reset_mechanism='zero',
                                        reset_delay=False,
                                        all_to_all=True)
        
        # Initialize the recurrent weight matrix:
        with torch.no_grad():
            nn.init.uniform_(self.reservoir_lif.recurrent.weight, a=0.1, b=1.0)
            W = self.reservoir_lif.recurrent.weight
            eigenvalues = torch.linalg.eigvals(W)
            current_radius = eigenvalues.abs().max()
            desired_radius = 1.5
            scaling_factor = desired_radius / current_radius
            W.mul_(scaling_factor)
        
        self.to(self.device)
    
    def forward(self, x):
        """
        Simulate the reservoir dynamics one time step at a time.
        
        Args:
            x (tensor): Input tensor of shape (batch_size, time_steps, 1).
            
        Returns:
            avg_firing_rate (float): Average firing rate (over neurons and time).
            spike_record (np.array): Reservoir spike record of shape (time_steps, batch_size, reservoir_size).
            mem_record (np.array): Reservoir membrane potential record (same shape as spike_record).
        """
        batch_size, time_steps, _ = x.shape
        x = x.to(self.device)
        
        # Initialize neuron states.
        input_mem = torch.zeros(batch_size, 1, device=self.device)
        reservoir_mem = torch.zeros(batch_size, self.reservoir_size, device=self.device)
        reservoir_spk = torch.zeros(batch_size, self.reservoir_size, device=self.device)
        
        spike_record = []
        mem_record = []
        
        for t in range(time_steps):
            x_t = x[:, t, :]  # shape: (batch_size, 1)
            input_current = self.input_fc(x_t)
            input_spk, input_mem = self.input_lif(input_current, input_mem)
            reservoir_current = self.reservoir_fc(input_spk)
            reservoir_spk, reservoir_mem = self.reservoir_lif(reservoir_current,
                                                              reservoir_spk,
                                                              reservoir_mem)
            spike_record.append(reservoir_spk.detach().cpu().numpy())
            mem_record.append(reservoir_mem.detach().cpu().numpy())
        
        spike_record = np.array(spike_record)  # shape: (time_steps, batch_size, reservoir_size)
        mem_record = np.array(mem_record)        # same shape
        avg_firing_rate = spike_record.mean()
        
        return avg_firing_rate, spike_record, mem_record
    
    def get_recurrent_weights(self):
        """Return the recurrent weight matrix as a numpy array."""
        return self.reservoir_lif.recurrent.weight.detach().cpu().numpy()

# =============================================================================
# 5. Define the Optuna Objective Function (Using a Grid Search)
# =============================================================================
def objective(trial):
    # Hyperparameters to tune.
    threshold = trial.suggest_float("threshold", 0.5, 5.0)
    beta_reservoir = trial.suggest_float("beta_reservoir", 0.01, 0.99)
    
    device = 'cpu'
    model = SpikingReservoirExp(threshold, beta_reservoir, reservoir_size=10, device=device)
    model.eval()
    
    # Use the unique output folder for saving the synthetic input plot.
    # (The folder path is provided later via trial.user_attrs.)
    output_folder = trial.user_attrs.get("output_folder")
    if output_folder is None:
        output_folder = "."
    x = generate_synthetic_input(output_folder)  # shape: (1, 1000, 1)
    
    avg_firing_rate, spike_record, mem_record = model(x)
    
    # Save extra information in the trial for later plotting.
    trial.set_user_attr("spike_record", spike_record)
    trial.set_user_attr("mem_record", mem_record)
    trial.set_user_attr("weights", model.get_recurrent_weights())
    
    return avg_firing_rate

# %%
# =============================================================================
# 6. Main Function: Run Grid Search, Save Plots, Hyperparameters, and Log to TensorBoard
# =============================================================================
if __name__ == '__main__':
    # Base directory for all output results.
    base_output_dir = "results"
    output_folder = create_unique_folder(base_output_dir)
    print(f"Output folder: {output_folder}")
    
    # Initialize TensorBoard writer with the unique output folder.
    writer = SummaryWriter(log_dir=output_folder)
    
    # Define grid search values for hyperparameters.
    threshold_values = np.linspace(0.1, 2.0, 20).tolist()  # n discrete values
    beta_values = np.linspace(0.01, 0.99, 20).tolist()       # m discrete values
    search_space = {
        "threshold": threshold_values,
        "beta_reservoir": beta_values
    }
    
    # Use Optuna's GridSampler.
    sampler = optuna.samplers.GridSampler(search_space)
    study = optuna.create_study(sampler=sampler, direction="maximize")
    
    # Pass the output folder path to each trial via user_attrs.
    def objective_with_folder(trial):
        trial.set_user_attr("output_folder", output_folder)
        return objective(trial)
    
    study.optimize(objective_with_folder, n_trials=len(threshold_values) * len(beta_values))
    
    # -----------------------------------------------------------------------------
    # (A) Extract Results for 3D Surface Plot and Heatmap
    # -----------------------------------------------------------------------------
    trials = study.trials
    # Prepare grids to store hyperparameter values and the corresponding firing rate.
    firing_rate_grid = np.zeros((len(threshold_values), len(beta_values)))
    for trial in trials:
        t_val = trial.params["threshold"]
        b_val = trial.params["beta_reservoir"]
        i = threshold_values.index(t_val)
        j = beta_values.index(b_val)
        firing_rate_grid[i, j] = trial.value
    
    # 1. 3D Surface Plot of the Average Firing Rate.
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    X, Y = np.meshgrid(beta_values, threshold_values)
    surf = ax.plot_surface(X, Y, firing_rate_grid, cmap='viridis', edgecolor='none')
    ax.set_xlabel('Beta Reservoir')
    ax.set_ylabel('Threshold')
    ax.set_zlabel('Avg Firing Rate')
    ax.set_title('3D Surface Plot of Avg Firing Rate')
    fig.colorbar(surf, shrink=0.5, aspect=5)
    plt.tight_layout()
    surface_path = os.path.join(output_folder, '3d_surface_plot.png')
    plt.savefig(surface_path)
    writer.add_figure("3D_Surface_Plot", fig)
    plt.close()
    
    # 2. Heatmap of the Average Firing Rate.
    plt.figure(figsize=(8, 6))
    plt.imshow(firing_rate_grid, origin='lower', aspect='auto',
               extent=[min(beta_values), max(beta_values), min(threshold_values), max(threshold_values)],
               cmap='viridis')
    plt.colorbar(label='Avg Firing Rate')
    plt.xlabel('Beta Reservoir')
    plt.ylabel('Threshold')
    plt.title('Heatmap of Avg Firing Rate')
    plt.tight_layout()
    heatmap_path = os.path.join(output_folder, 'heatmap_firing_rate.png')
    plt.savefig(heatmap_path)
    writer.add_figure("Heatmap_Firing_Rate", plt.gcf())
    plt.close()
    
    # -----------------------------------------------------------------------------
    # (B) Choose a Representative Trial for Detailed Plots
    # -----------------------------------------------------------------------------
    # For example, choose the trial with hyperparameters closest to the grid center.
    rep_threshold = threshold_values[len(threshold_values)//2]
    rep_beta = beta_values[len(beta_values)//2]
    rep_trial = None
    for trial in trials:
        if trial.params["threshold"] == rep_threshold and trial.params["beta_reservoir"] == rep_beta:
            rep_trial = trial
            break
    if rep_trial is None:
        rep_trial = trials[0]
    
    # Save the hyperparameters of the representative trial to a file.
    hyperparams_file = os.path.join(output_folder, "hyperparameters.txt")
    with open(hyperparams_file, "w") as f:
        f.write("Representative Trial Hyperparameters:\n")
        for key, value in rep_trial.params.items():
            f.write(f"{key}: {value}\n")
    
    # Retrieve recorded data from the representative trial.
    spike_record = rep_trial.user_attrs["spike_record"]  # shape: (time_steps, 1, reservoir_size)
    mem_record = rep_trial.user_attrs["mem_record"]        # same shape
    weights = rep_trial.user_attrs["weights"]
    
    # Remove the batch dimension (batch_size=1).
    spike_record = spike_record[:, 0, :]  # shape: (time_steps, reservoir_size)
    mem_record = mem_record[:, 0, :]        # shape: (time_steps, reservoir_size)
    time_steps = spike_record.shape[0]
    
    # -----------------------------------------------------------------------------
    # (C) Detailed Plots for the Representative Trial
    # -----------------------------------------------------------------------------
    # 1. Spike Raster Plot.
    plt.figure(figsize=(10, 6))
    for neuron in range(spike_record.shape[1]):
        spike_times = np.where(spike_record[:, neuron] > 0)[0]
        plt.scatter(spike_times, np.full_like(spike_times, neuron), s=10)
    plt.xlabel('Time Step')
    plt.ylabel('Neuron Index')
    plt.title('Spike Raster Plot')
    plt.yticks(range(spike_record.shape[1]))
    plt.grid(True)
    plt.tight_layout()
    spike_raster_path = os.path.join(output_folder, 'spike_raster_plot.png')
    plt.savefig(spike_raster_path)
    writer.add_figure("Spike_Raster_Plot", plt.gcf())
    plt.close()
    
    # 2. Membrane Potential Traces.
    plt.figure(figsize=(10, 6))
    for neuron in range(mem_record.shape[1]):
        plt.plot(mem_record[:, neuron], label=f'Neuron {neuron}')
    plt.xlabel('Time Step')
    plt.ylabel('Membrane Potential')
    plt.title('Membrane Potential Traces')
    plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
    plt.grid(True)
    plt.tight_layout()
    mem_trace_path = os.path.join(output_folder, 'membrane_potential_traces.png')
    plt.savefig(mem_trace_path)
    writer.add_figure("Membrane_Potential_Traces", plt.gcf())
    plt.close()
    
    # 3. Inter-Spike Interval (ISI) Histogram.
    all_intervals = []
    for neuron in range(spike_record.shape[1]):
        spike_times = np.where(spike_record[:, neuron] > 0)[0]
        if len(spike_times) > 1:
            intervals = np.diff(spike_times)
            all_intervals.extend(intervals)
    plt.figure(figsize=(8, 6))
    plt.hist(all_intervals, bins=30, color='skyblue', edgecolor='black')
    plt.xlabel('Inter-Spike Interval (Time Steps)')
    plt.ylabel('Count')
    plt.title('Inter-Spike Interval Histogram')
    plt.grid(True)
    plt.tight_layout()
    isi_path = os.path.join(output_folder, 'isi_histogram.png')
    plt.savefig(isi_path)
    writer.add_figure("ISI_Histogram", plt.gcf())
    plt.close()
    
    # 4. Recurrent Weight Matrix Heatmap.
    plt.figure(figsize=(6, 5))
    plt.imshow(weights, cmap='inferno', aspect='auto')
    plt.colorbar(label='Weight Value')
    plt.xlabel('Post-synaptic Neuron')
    plt.ylabel('Pre-synaptic Neuron')
    plt.title('Recurrent Weight Matrix Heatmap')
    plt.tight_layout()
    weight_heatmap_path = os.path.join(output_folder, 'weight_matrix_heatmap.png')
    plt.savefig(weight_heatmap_path)
    writer.add_figure("Weight_Matrix_Heatmap", plt.gcf())
    plt.close()
    
    # 5. Eigenvalues of the Recurrent Weight Matrix.
    eigenvalues = np.linalg.eigvals(weights)
    plt.figure(figsize=(8, 6))
    plt.scatter(eigenvalues.real, eigenvalues.imag, c='purple', edgecolors='k')
    plt.xlabel('Real Part')
    plt.ylabel('Imaginary Part')
    plt.title('Eigenvalues of the Recurrent Weight Matrix')
    plt.grid(True)
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.tight_layout()
    eigen_path = os.path.join(output_folder, 'eigenvalues.png')
    plt.savefig(eigen_path)
    writer.add_figure("Eigenvalues", plt.gcf())
    plt.close()
    
    # Log weight histogram to TensorBoard.
    writer.add_histogram("Recurrent_Weights", weights, global_step=0)
    
    # Log the average firing rate from the representative trial.
    writer.add_scalar("Representative_Avg_Firing_Rate", rep_trial.value, global_step=0)
    
    # Log hyperparameters using TensorBoard's hparams API.
    writer.add_hparams(rep_trial.params, {"hparam/avg_firing_rate": rep_trial.value})
    
    writer.close()
    print("All plots and logs have been saved.")
# Out:
# [I 2025-02-13 13:10:40,053] A new study created in memory with name: no-name-00e4d64c-4adf-41b6-9208-654708328a24
# Output folder: results/trial_15_date_2025_02_13_13_10
# [I 2025-02-13 13:10:40,409] Trial 0 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.3194736842105263}. Best is trial 0 with value: 0.0.
# [I 2025-02-13 13:10:40,742] Trial 1 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.7836842105263158}. Best is trial 0 with value: 0.0.
# /opt/anaconda3/envs/NeuroVecio/lib/python3.9/site-packages/optuna/samplers/_grid.py:199: UserWarning: The value `0.2` is out of range of the parameter `threshold`. The value will be used but the actual distribution is: `FloatDistribution(high=5.0, log=False, low=0.5, step=None)`.
#   warnings.warn(
# [I 2025-02-13 13:10:41,039] Trial 2 finished with value: 0.9993000030517578 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.8868421052631579}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:41,383] Trial 3 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.47421052631578947}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:41,676] Trial 4 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.6289473684210526}. Best is trial 2 with value: 0.9993000030517578.
# /opt/anaconda3/envs/NeuroVecio/lib/python3.9/site-packages/optuna/samplers/_grid.py:199: UserWarning: The value `0.1` is out of range of the parameter `threshold`. The value will be used but the actual distribution is: `FloatDistribution(high=5.0, log=False, low=0.5, step=None)`.
#   warnings.warn(
# [I 2025-02-13 13:10:41,975] Trial 5 finished with value: 0.9990000128746033 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.16473684210526315}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:42,273] Trial 6 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.37105263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:42,574] Trial 7 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.6805263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:42,920] Trial 8 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.37105263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:43,213] Trial 9 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.5257894736842105}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:43,508] Trial 10 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.06157894736842105}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:43,808] Trial 11 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.3194736842105263}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:44,102] Trial 12 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.26789473684210524}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:44,458] Trial 13 finished with value: 0.024900000542402267 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.8868421052631579}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:44,764] Trial 14 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.01}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:45,063] Trial 15 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.1131578947368421}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:45,363] Trial 16 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.7321052631578947}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:45,661] Trial 17 finished with value: 0.9987000226974487 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.37105263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:45,962] Trial 18 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.5257894736842105}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:46,318] Trial 19 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.47421052631578947}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:46,675] Trial 20 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.4226315789473684}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:46,977] Trial 21 finished with value: 0.0284000001847744 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.6805263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:47,273] Trial 22 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.3194736842105263}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:47,568] Trial 23 finished with value: 0.9965000152587891 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.8868421052631579}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:47,865] Trial 24 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.4226315789473684}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:48,159] Trial 25 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.7836842105263158}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:48,525] Trial 26 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.16473684210526315}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:48,817] Trial 27 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.01}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:49,163] Trial 28 finished with value: 0.016599999740719795 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.7321052631578947}. Best is trial 2 with value: 0.9993000030517578.
# /opt/anaconda3/envs/NeuroVecio/lib/python3.9/site-packages/optuna/samplers/_grid.py:199: UserWarning: The value `0.3` is out of range of the parameter `threshold`. The value will be used but the actual distribution is: `FloatDistribution(high=5.0, log=False, low=0.5, step=None)`.
#   warnings.warn(
# [I 2025-02-13 13:10:49,458] Trial 29 finished with value: 0.9987000226974487 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.26789473684210524}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:49,782] Trial 30 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.4226315789473684}. Best is trial 2 with value: 0.9993000030517578.
# /opt/anaconda3/envs/NeuroVecio/lib/python3.9/site-packages/optuna/samplers/_grid.py:199: UserWarning: The value `0.4` is out of range of the parameter `threshold`. The value will be used but the actual distribution is: `FloatDistribution(high=5.0, log=False, low=0.5, step=None)`.
#   warnings.warn(
# [I 2025-02-13 13:10:50,081] Trial 31 finished with value: 0.9973999857902527 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.7836842105263158}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:50,376] Trial 32 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.8352631578947368}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:50,680] Trial 33 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.5773684210526315}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:50,974] Trial 34 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.16473684210526315}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:51,262] Trial 35 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.16473684210526315}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:51,652] Trial 36 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.2163157894736842}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:51,947] Trial 37 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.4226315789473684}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:52,239] Trial 38 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.4226315789473684}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:52,533] Trial 39 finished with value: 0.03310000151395798 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.99}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:52,822] Trial 40 finished with value: 0.9984999895095825 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.26789473684210524}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:53,115] Trial 41 finished with value: 0.9980999827384949 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.8352631578947368}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:53,408] Trial 42 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.01}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:53,705] Trial 43 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.01}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:53,998] Trial 44 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.7321052631578947}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:54,290] Trial 45 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.1131578947368421}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:54,595] Trial 46 finished with value: 0.06920000165700912 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.9384210526315789}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:54,985] Trial 47 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.6289473684210526}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:55,275] Trial 48 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.37105263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:55,574] Trial 49 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.5773684210526315}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:55,868] Trial 50 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.6289473684210526}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:56,165] Trial 51 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.37105263157894736}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:56,458] Trial 52 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.7321052631578947}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:56,756] Trial 53 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.4226315789473684}. Best is trial 2 with value: 0.9993000030517578.
# [I 2025-02-13 13:10:57,053] Trial 54 finished with value: 0.9994000196456909 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.7321052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:57,353] Trial 55 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.7836842105263158}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:57,647] Trial 56 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.1131578947368421}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:57,942] Trial 57 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:58,231] Trial 58 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.06157894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:58,524] Trial 59 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.1131578947368421}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:58,829] Trial 60 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.16473684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:59,255] Trial 61 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.6805263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:59,553] Trial 62 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:10:59,848] Trial 63 finished with value: 0.04100000113248825 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.8868421052631579}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:00,150] Trial 64 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.47421052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:00,439] Trial 65 finished with value: 0.4406000077724457 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:00,737] Trial 66 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:01,031] Trial 67 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:01,321] Trial 68 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:01,618] Trial 69 finished with value: 0.016599999740719795 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.7836842105263158}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:01,909] Trial 70 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:02,207] Trial 71 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.6805263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:02,498] Trial 72 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.16473684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:02,794] Trial 73 finished with value: 0.9986000061035156 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.06157894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:03,086] Trial 74 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.26789473684210524}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:03,380] Trial 75 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:03,676] Trial 76 finished with value: 0.9979000091552734 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:03,971] Trial 77 finished with value: 0.9966999888420105 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.7836842105263158}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:04,266] Trial 78 finished with value: 0.9990000128746033 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:04,685] Trial 79 finished with value: 0.06129999831318855 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.8352631578947368}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:05,031] Trial 80 finished with value: 0.006200000178068876 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.8352631578947368}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:05,322] Trial 81 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.16473684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:05,619] Trial 82 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.1131578947368421}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:05,914] Trial 83 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.26789473684210524}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:06,237] Trial 84 finished with value: 0.9987000226974487 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.7836842105263158}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:06,530] Trial 85 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.5773684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:06,833] Trial 86 finished with value: 0.0 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.3194736842105263}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:07,146] Trial 87 finished with value: 0.22769999504089355 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:07,453] Trial 88 finished with value: 0.0608999989926815 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.99}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:07,753] Trial 89 finished with value: 0.9911999702453613 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.8352631578947368}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:08,050] Trial 90 finished with value: 0.9976999759674072 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.99}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:08,368] Trial 91 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.6289473684210526}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:08,666] Trial 92 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.1131578947368421}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:08,962] Trial 93 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:09,258] Trial 94 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.47421052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:09,559] Trial 95 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:09,860] Trial 96 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.3194736842105263}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:10,159] Trial 97 finished with value: 0.15389999747276306 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.99}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:10,457] Trial 98 finished with value: 0.9943000078201294 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.6805263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:10,757] Trial 99 finished with value: 0.9950000047683716 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:11,217] Trial 100 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.6289473684210526}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:11,516] Trial 101 finished with value: 0.0 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.16473684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:11,816] Trial 102 finished with value: 0.008999999612569809 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.7836842105263158}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:12,114] Trial 103 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:12,409] Trial 104 finished with value: 0.9966999888420105 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.7321052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:12,722] Trial 105 finished with value: 0.9991999864578247 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.8868421052631579}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:13,019] Trial 106 finished with value: 0.9986000061035156 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.2163157894736842}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:13,317] Trial 107 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.8868421052631579}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:13,614] Trial 108 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:13,912] Trial 109 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.7321052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:14,213] Trial 110 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.2163157894736842}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:14,511] Trial 111 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.2163157894736842}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:14,812] Trial 112 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.7321052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:15,115] Trial 113 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.06157894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:15,414] Trial 114 finished with value: 0.9912999868392944 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:15,713] Trial 115 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.5257894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:16,013] Trial 116 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.6289473684210526}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:16,312] Trial 117 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.1131578947368421}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:16,614] Trial 118 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.5773684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:16,909] Trial 119 finished with value: 0.9980000257492065 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.8868421052631579}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:17,207] Trial 120 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.2163157894736842}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:17,507] Trial 121 finished with value: 0.0 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.5773684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:17,813] Trial 122 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.5773684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:18,163] Trial 123 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.5773684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:18,466] Trial 124 finished with value: 0.02280000038444996 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.9384210526315789}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:18,768] Trial 125 finished with value: 0.0 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:19,239] Trial 126 finished with value: 0.998199999332428 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.06157894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:19,539] Trial 127 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.6289473684210526}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:19,838] Trial 128 finished with value: 0.4447999894618988 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.8868421052631579}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:20,137] Trial 129 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.4226315789473684}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:20,434] Trial 130 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.37105263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:20,740] Trial 131 finished with value: 0.11900000274181366 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.99}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:21,045] Trial 132 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.16473684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:21,344] Trial 133 finished with value: 0.9991999864578247 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.6289473684210526}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:21,647] Trial 134 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.5257894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:21,998] Trial 135 finished with value: 0.9979000091552734 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.26789473684210524}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:22,295] Trial 136 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.7836842105263158}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:22,601] Trial 137 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.47421052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:22,899] Trial 138 finished with value: 0.04650000110268593 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.8352631578947368}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:23,198] Trial 139 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.01}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:23,498] Trial 140 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.4226315789473684}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:23,802] Trial 141 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.47421052631578947}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:24,106] Trial 142 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.06157894736842105}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:24,404] Trial 143 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.26789473684210524}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:24,711] Trial 144 finished with value: 0.9916999936103821 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.6805263157894736}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:25,016] Trial 145 finished with value: 0.0 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.26789473684210524}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:25,322] Trial 146 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.8868421052631579}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:25,630] Trial 147 finished with value: 0.9937000274658203 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.6289473684210526}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:25,997] Trial 148 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.5773684210526315}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:26,300] Trial 149 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.26789473684210524}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:26,616] Trial 150 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.8352631578947368}. Best is trial 54 with value: 0.9994000196456909.
# [I 2025-02-13 13:11:27,019] Trial 151 finished with value: 0.9994999766349792 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.3194736842105263}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:27,364] Trial 152 finished with value: 0.3944999873638153 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.7321052631578947}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:27,690] Trial 153 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.26789473684210524}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:28,012] Trial 154 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.5257894736842105}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:28,331] Trial 155 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.3194736842105263}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:28,646] Trial 156 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.6805263157894736}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:28,967] Trial 157 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.3194736842105263}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:29,539] Trial 158 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.47421052631578947}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:29,850] Trial 159 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.7321052631578947}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:30,152] Trial 160 finished with value: 0.998199999332428 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.7321052631578947}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:30,458] Trial 161 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.3194736842105263}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:30,784] Trial 162 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.06157894736842105}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:31,087] Trial 163 finished with value: 0.03350000083446503 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.9384210526315789}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:31,388] Trial 164 finished with value: 0.9973000288009644 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.4226315789473684}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:31,694] Trial 165 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.06157894736842105}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:32,004] Trial 166 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.5773684210526315}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:32,324] Trial 167 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.2163157894736842}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:32,629] Trial 168 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.2163157894736842}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:32,929] Trial 169 finished with value: 0.9990000128746033 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.16473684210526315}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:33,247] Trial 170 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.4226315789473684}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:33,558] Trial 171 finished with value: 0.9976000189781189 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.7321052631578947}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:33,872] Trial 172 finished with value: 0.9993000030517578 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.5257894736842105}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:34,209] Trial 173 finished with value: 0.39959999918937683 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.99}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:34,515] Trial 174 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.5773684210526315}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:34,832] Trial 175 finished with value: 0.09939999878406525 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.7321052631578947}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:35,137] Trial 176 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.26789473684210524}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:35,443] Trial 177 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.1131578947368421}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:35,748] Trial 178 finished with value: 0.9991000294685364 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.8352631578947368}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:36,053] Trial 179 finished with value: 0.02669999934732914 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.99}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:36,399] Trial 180 finished with value: 0.9908000230789185 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.5773684210526315}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:36,706] Trial 181 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.16473684210526315}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:37,010] Trial 182 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.3194736842105263}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:37,316] Trial 183 finished with value: 0.9991999864578247 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.99}. Best is trial 151 with value: 0.9994999766349792.
# [I 2025-02-13 13:11:37,627] Trial 184 finished with value: 0.9997000098228455 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.5773684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:37,931] Trial 185 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:38,236] Trial 186 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:38,544] Trial 187 finished with value: 0.9976000189781189 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:38,856] Trial 188 finished with value: 0.9991000294685364 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:39,163] Trial 189 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:39,464] Trial 190 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:39,772] Trial 191 finished with value: 0.13619999587535858 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:40,079] Trial 192 finished with value: 0.018300000578165054 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:40,382] Trial 193 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:40,688] Trial 194 finished with value: 0.0 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.01}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:40,992] Trial 195 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:41,296] Trial 196 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.37105263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:41,906] Trial 197 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:42,211] Trial 198 finished with value: 0.13680000603199005 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:42,512] Trial 199 finished with value: 0.9984999895095825 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.5773684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:42,817] Trial 200 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.3194736842105263}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:43,122] Trial 201 finished with value: 0.0 and parameters: {'threshold': 1.7, 'beta_reservoir': 0.5773684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:43,426] Trial 202 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:43,735] Trial 203 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:44,038] Trial 204 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:44,346] Trial 205 finished with value: 0.994700014591217 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.7836842105263158}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:44,669] Trial 206 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.5773684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:44,976] Trial 207 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:45,282] Trial 208 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:45,586] Trial 209 finished with value: 0.4221999943256378 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:45,889] Trial 210 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.16473684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:46,195] Trial 211 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:46,502] Trial 212 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:46,808] Trial 213 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:47,112] Trial 214 finished with value: 0.9987999796867371 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:47,416] Trial 215 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.3194736842105263}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:47,722] Trial 216 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:48,025] Trial 217 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.26789473684210524}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:48,329] Trial 218 finished with value: 0.0 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:48,636] Trial 219 finished with value: 0.520799994468689 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:48,942] Trial 220 finished with value: 0.9975000023841858 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:49,250] Trial 221 finished with value: 0.9950000047683716 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:49,556] Trial 222 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:49,864] Trial 223 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.01}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:50,170] Trial 224 finished with value: 0.9958000183105469 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.7321052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:50,473] Trial 225 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.16473684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:50,831] Trial 226 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:51,139] Trial 227 finished with value: 0.24469999969005585 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:51,453] Trial 228 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.16473684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:51,762] Trial 229 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.01}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:52,071] Trial 230 finished with value: 0.9944999814033508 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:52,374] Trial 231 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:52,680] Trial 232 finished with value: 0.996999979019165 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:53,057] Trial 233 finished with value: 0.9865000247955322 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:53,365] Trial 234 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.5773684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:53,673] Trial 235 finished with value: 0.9991999864578247 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:53,978] Trial 236 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.26789473684210524}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:54,283] Trial 237 finished with value: 0.9983000159263611 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:54,586] Trial 238 finished with value: 0.0 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:54,891] Trial 239 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:11:55,195] Trial 240 finished with value: 0.030899999663233757 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# ...
# [I 2025-02-13 13:12:21,198] Trial 319 finished with value: 0.9988999962806702 and parameters: {'threshold': 0.1, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:21,549] Trial 320 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.3194736842105263}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:21,865] Trial 321 finished with value: 0.009600000455975533 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:22,175] Trial 322 finished with value: 0.06920000165700912 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:22,489] Trial 323 finished with value: 0.9975000023841858 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:22,815] Trial 324 finished with value: 0.9975000023841858 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:23,134] Trial 325 finished with value: 0.9975000023841858 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:23,446] Trial 326 finished with value: 0.0 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:23,754] Trial 327 finished with value: 0.998199999332428 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.3194736842105263}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:24,068] Trial 328 finished with value: 0.9930999875068665 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:24,380] Trial 329 finished with value: 0.008999999612569809 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:24,763] Trial 330 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:25,075] Trial 331 finished with value: 0.996999979019165 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:25,398] Trial 332 finished with value: 0.016599999740719795 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:25,766] Trial 333 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.26789473684210524}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:26,082] Trial 334 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.7321052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:26,391] Trial 335 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:26,703] Trial 336 finished with value: 0.9987999796867371 and parameters: {'threshold': 0.2, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:27,016] Trial 337 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:27,327] Trial 338 finished with value: 0.011099999770522118 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:27,639] Trial 339 finished with value: 0.9983000159263611 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:27,947] Trial 340 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.26789473684210524}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:28,258] Trial 341 finished with value: 0.9358999729156494 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:28,565] Trial 342 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:28,874] Trial 343 finished with value: 0.03610000014305115 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:29,186] Trial 344 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:29,496] Trial 345 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:29,810] Trial 346 finished with value: 0.9890999794006348 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:30,122] Trial 347 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.3194736842105263}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:30,436] Trial 348 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.7321052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:30,780] Trial 349 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:31,093] Trial 350 finished with value: 0.9962999820709229 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:31,403] Trial 351 finished with value: 0.9955000281333923 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:31,720] Trial 352 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.37105263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:32,035] Trial 353 finished with value: 0.9965999722480774 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:32,460] Trial 354 finished with value: 0.9976999759674072 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:32,879] Trial 355 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:33,215] Trial 356 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:33,540] Trial 357 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.3194736842105263}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:33,856] Trial 358 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:34,169] Trial 359 finished with value: 0.06520000100135803 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:34,481] Trial 360 finished with value: 0.0284000001847744 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.7321052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:34,793] Trial 361 finished with value: 0.9983000159263611 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:35,110] Trial 362 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.37105263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:35,423] Trial 363 finished with value: 0.9944999814033508 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.7321052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:35,736] Trial 364 finished with value: 0.4717999994754791 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.9384210526315789}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:36,050] Trial 365 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:36,361] Trial 366 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:36,677] Trial 367 finished with value: 0.0 and parameters: {'threshold': 1.9, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:36,992] Trial 368 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:37,306] Trial 369 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:37,619] Trial 370 finished with value: 0.9959999918937683 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:37,928] Trial 371 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.26789473684210524}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:38,246] Trial 372 finished with value: 0.9927999973297119 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:38,560] Trial 373 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.16473684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:38,873] Trial 374 finished with value: 0.038600001484155655 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:39,190] Trial 375 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:39,517] Trial 376 finished with value: 0.0 and parameters: {'threshold': 0.6, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:39,865] Trial 377 finished with value: 0.004999999888241291 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:41,280] Trial 378 finished with value: 0.9976999759674072 and parameters: {'threshold': 0.5, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:41,699] Trial 379 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:42,357] Trial 380 finished with value: 0.9933000206947327 and parameters: {'threshold': 0.7, 'beta_reservoir': 0.99}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:42,707] Trial 381 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.06157894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:43,044] Trial 382 finished with value: 0.0 and parameters: {'threshold': 1.4, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:43,370] Trial 383 finished with value: 0.0 and parameters: {'threshold': 1.5, 'beta_reservoir': 0.7836842105263158}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:43,698] Trial 384 finished with value: 0.0 and parameters: {'threshold': 0.8999999999999999, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:44,012] Trial 385 finished with value: 0.0 and parameters: {'threshold': 1.0999999999999999, 'beta_reservoir': 0.16473684210526315}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:44,332] Trial 386 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.2163157894736842}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:44,654] Trial 387 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.7321052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:44,973] Trial 388 finished with value: 0.9976999759674072 and parameters: {'threshold': 0.3, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:45,296] Trial 389 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.6805263157894736}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:45,611] Trial 390 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.5257894736842105}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:45,926] Trial 391 finished with value: 0.0 and parameters: {'threshold': 0.9999999999999999, 'beta_reservoir': 0.01}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:46,379] Trial 392 finished with value: 0.0 and parameters: {'threshold': 2.0, 'beta_reservoir': 0.8868421052631579}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:46,736] Trial 393 finished with value: 0.0 and parameters: {'threshold': 1.5999999999999999, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:47,060] Trial 394 finished with value: 0.0 and parameters: {'threshold': 1.2, 'beta_reservoir': 0.6289473684210526}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:47,379] Trial 395 finished with value: 0.9977999925613403 and parameters: {'threshold': 0.4, 'beta_reservoir': 0.8352631578947368}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:47,704] Trial 396 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.47421052631578947}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:48,021] Trial 397 finished with value: 0.0 and parameters: {'threshold': 1.8, 'beta_reservoir': 0.26789473684210524}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:48,344] Trial 398 finished with value: 0.0 and parameters: {'threshold': 0.7999999999999999, 'beta_reservoir': 0.1131578947368421}. Best is trial 184 with value: 0.9997000098228455.
# [I 2025-02-13 13:12:48,692] Trial 399 finished with value: 0.0 and parameters: {'threshold': 1.3, 'beta_reservoir': 0.4226315789473684}. Best is trial 184 with value: 0.9997000098228455.
# All plots and logs have been saved.
