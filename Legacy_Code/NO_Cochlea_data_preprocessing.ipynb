# %%
import os
import wave
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import spectrogram
import librosa
import librosa.display
import soundfile as sf

img_dpi = 600

# %%
def read_wav(file_path, duration_minutes=1, prints=False):
    """
    Read a .wav file and return the mono audio data for the first specified duration.

    Parameters:
    file_path (str): Path to the .wav file.
    duration_minutes (int): Duration to read in minutes.

    Returns:
    mono_audio (ndarray): Mono audio data.
    sample_rate (int): Sampling rate of the audio file.
    info_str (str): String containing information about the audio.
    """
    with wave.open(file_path, 'rb') as wav_file:
        # Get parameters
        num_channels = wav_file.getnchannels()
        sample_rate = wav_file.getframerate()
        sampwidth = wav_file.getsampwidth() * 8  # Sample width in bits
        num_frames = wav_file.getnframes()

        # Calculate the number of samples for the desired duration
        max_samples = int(60 * duration_minutes * sample_rate)

        # Read only the required number of frames
        frames_to_read = min(num_frames, max_samples)
        frames = wav_file.readframes(frames_to_read)
        audio_data = np.frombuffer(frames, dtype=np.int16)

        # Reshape to separate channels if stereo
        if num_channels > 1:
            audio_data = audio_data.reshape(-1, num_channels)
            # Convert stereo to mono by averaging channels
            mono_audio = audio_data.mean(axis=1)
        else:
            mono_audio = audio_data

        # Calculate actual duration
        duration_sec = frames_to_read / sample_rate
        duration_min = duration_sec / 60

        # Calculate additional statistics
        peak_amplitude = np.max(np.abs(mono_audio))
        rms_amplitude = np.sqrt(np.mean(mono_audio**2))
        zero_crossings = ((mono_audio[:-1] * mono_audio[1:]) < 0).sum()
        zero_crossing_rate = zero_crossings / duration_sec

        # Collect information into a string
        info_str = (
            f"File: {os.path.basename(file_path)}\n"
            f"Number of channels: {num_channels}\n"
            f"Sample rate: {sample_rate} Hz\n"
            f"Sample width: {sampwidth} bits\n"
            f"Number of frames: {num_frames}\n"
            f"Frames read: {frames_to_read}\n"
            f"Max samples to read (for {duration_minutes} minutes): {max_samples}\n"
            f"Type of frames: {type(frames)}\n"
            f"Length of frames: {len(frames)} bytes\n"
            f"Duration of audio data: {duration_sec:.2f} seconds (== {duration_min:.2f} minutes)\n"
            f"Shape of mono audio data: {mono_audio.shape}\n"
            f"Max value of mono audio data: {np.max(mono_audio)}\n"
            f"Min value of mono audio data: {np.min(mono_audio)}\n"
            f"Average value of mono audio data: {np.mean(mono_audio)}\n"
            f"Peak amplitude: {peak_amplitude}\n"
            f"RMS amplitude: {rms_amplitude:.2f}\n"
            f"Zero-crossing rate: {zero_crossing_rate:.2f} crossings/sec"
        )

        # Print information if requested
        if prints:
            print(info_str)

        return mono_audio, sample_rate, info_str

def plot_waveform(signal, sample_rate, title, output_filename_base):
    """
    Plot the waveform of the audio signal.
    """
    times = np.arange(len(signal)) / sample_rate
    plt.figure(figsize=(12, 4))
    plt.plot(times, signal, linewidth=0.1)
    plt.title(f"Waveform: {title}")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.tight_layout()
    plt.savefig(output_filename_base + '_waveform.png', dpi=img_dpi)
    plt.savefig(output_filename_base + '_waveform.pdf', dpi=img_dpi)
    plt.close()

def plot_spectrogram(signal, sample_rate, title, output_filename_base):
    """
    Plot the spectrogram of the audio signal.
    """
    f, t, Sxx = spectrogram(signal, sample_rate, nperseg=1024)
    plt.figure(figsize=(12, 4))
    plt.pcolormesh(t, f, 10 * np.log10(Sxx), shading='gouraud')
    plt.title(f"Spectrogram: {title}")
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [sec]')
    plt.colorbar(label='Intensity [dB]')
    plt.tight_layout()
    plt.savefig(output_filename_base + '_spectrogram.png', dpi=img_dpi)
    plt.savefig(output_filename_base + '_spectrogram.pdf', dpi=img_dpi)
    plt.close()

def plot_frequency_spectrum(signal, sample_rate, title, output_filename_base):
    """
    Plot the frequency spectrum of the audio signal.
    """
    freqs = np.fft.rfftfreq(len(signal), d=1/sample_rate)
    fft_spectrum = np.abs(np.fft.rfft(signal))
    plt.figure(figsize=(12, 4))
    plt.plot(freqs, fft_spectrum, linewidth=0.1)
    plt.title(f"Frequency Spectrum: {title}")
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.tight_layout()
    plt.savefig(output_filename_base + '_frequency_spectrum.png', dpi=img_dpi)
    plt.savefig(output_filename_base + '_frequency_spectrum.pdf', dpi=img_dpi)
    plt.close()

def plot_mel_spectrogram(signal, sample_rate, title, output_filename_base):
    """
    Plot the mel spectrogram of the audio signal.
    """
    # Convert signal to float and normalize
    signal = signal.astype(float) / np.max(np.abs(signal))
    S = librosa.feature.melspectrogram(y=signal, sr=sample_rate, n_mels=128)
    S_dB = librosa.power_to_db(S, ref=np.max)
    plt.figure(figsize=(12, 4))
    librosa.display.specshow(S_dB, sr=sample_rate, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title(f"Mel Spectrogram: {title}")
    plt.tight_layout()
    plt.savefig(output_filename_base + '_mel_spectrogram.png', dpi=img_dpi)
    plt.savefig(output_filename_base + '_mel_spectrogram.pdf', dpi=img_dpi)
    plt.close()

def plot_waveform_and_info(signal, sample_rate, title, output_filename_base, info_str):
    """
    Plot the waveform and include information text.
    """
    times = np.arange(len(signal)) / sample_rate
    plt.figure(figsize=(12, 8))  # Increased size for better quality
    plt.subplot(2, 1, 1)
    plt.plot(times, signal, linewidth=0.1)
    plt.title(f"Waveform: {title}", fontsize=14)
    plt.xlabel('Time (s)', fontsize=12)
    plt.ylabel('Amplitude', fontsize=12)

    plt.subplot(2, 1, 2)
    plt.axis('off')
    plt.text(0.01, 0.5, info_str, fontsize=10, va='center', ha='left', wrap=True)

    plt.tight_layout()
    plt.savefig(output_filename_base + '_waveform_info.png', dpi=img_dpi)
    plt.savefig(output_filename_base + '_waveform_info.pdf', dpi=img_dpi)
    plt.close()

def process_audio_file(file_path, duration_minutes=1, save_directory='.', prints=False):
    """
    Process a single audio file, generate plots and print information.
    """
    if not os.path.exists(save_directory):
        os.makedirs(save_directory)

    # Read the wav file
    mono_audio, sample_rate, info_str = read_wav(file_path, duration_minutes, prints=prints)

    # Prepare the output filename base
    filename = os.path.basename(file_path)
    output_filename_base = os.path.join(save_directory, os.path.splitext(filename)[0])

    # Generate plots
    plot_waveform_and_info(mono_audio, sample_rate, filename, output_filename_base, info_str)
    #plot_spectrogram(mono_audio, sample_rate, filename, output_filename_base)
    #plot_frequency_spectrum(mono_audio, sample_rate, filename, output_filename_base)
    #plot_mel_spectrogram(mono_audio, sample_rate, filename, output_filename_base)

    # Additional prints
    if prints:
        print("\nProcessing complete. Plots saved to:", save_directory)

# %%
file_name = 'CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav'
load_directory = 'data/PROCESSED/16kHz_resampling_zero_clipped/'
save_directory = 'data/PROCESSED/plots/16kHz_resampling_zero_clipped/CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav'

# Build the full file path
file_path = os.path.join(load_directory, file_name)

read_wav(file_path, duration_minutes=30, prints=True)

process_audio_file(file_path, duration_minutes=30, save_directory=save_directory, prints=True)
# Out:
# File: CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav
# Number of channels: 2
# Sample rate: 16000 Hz
# Sample width: 16 bits
# Number of frames: 29760000
# Frames read: 28800000
# Max samples to read (for 30 minutes): 28800000
# Type of frames: <class 'bytes'>
# Length of frames: 115200000 bytes
# Duration of audio data: 1800.00 seconds (== 30.00 minutes)
# Shape of mono audio data: (28800000,)
# Max value of mono audio data: 32767.0
# Min value of mono audio data: 0.0
# Average value of mono audio data: 490.88977553819444
# Peak amplitude: 32767.0
# RMS amplitude: 932.70
# Zero-crossing rate: 0.00 crossings/sec
# File: CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav
# Number of channels: 2
# Sample rate: 16000 Hz
# Sample width: 16 bits
# Number of frames: 29760000
# Frames read: 28800000
# Max samples to read (for 30 minutes): 28800000
# Type of frames: <class 'bytes'>
# Length of frames: 115200000 bytes
# Duration of audio data: 1800.00 seconds (== 30.00 minutes)
# Shape of mono audio data: (28800000,)
# Max value of mono audio data: 32767.0
# Min value of mono audio data: 0.0
# Average value of mono audio data: 490.88977553819444
# Peak amplitude: 32767.0
# RMS amplitude: 932.70
# Zero-crossing rate: 0.00 crossings/sec
#
# Processing complete. Plots saved to: data/PROCESSED/plots/16kHz_resampling_zero_clipped/CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav

# %% [markdown]
# ## Data preprocessing 1 prefix at a time

# %%
import os
import wave
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import spectrogram
import librosa
import librosa.display
import soundfile as sf

img_dpi = 900

# read_wav, plot_waveform, plot_spectrogram, plot_frequency_spectrum, plot_mel_spectrogram, and plot_waveform_and_info. These functions remain unchanged.

def process_audio_file(file_path, duration_minutes=1, save_directory='.', prints=False):
    """
    Process a single audio file, generate plots, and print information.
    """
    if not os.path.exists(save_directory):
        os.makedirs(save_directory)

    # Read the wav file
    mono_audio, sample_rate, info_str = read_wav(file_path, duration_minutes, prints=prints)

    # Prepare the output filename base
    filename = os.path.basename(file_path)
    output_filename_base = os.path.join(save_directory, os.path.splitext(filename)[0])

    # Generate plots
    plot_waveform_and_info(mono_audio, sample_rate, filename, output_filename_base, info_str)
    plot_spectrogram(mono_audio, sample_rate, filename, output_filename_base)
    plot_frequency_spectrum(mono_audio, sample_rate, filename, output_filename_base)
    plot_mel_spectrogram(mono_audio, sample_rate, filename, output_filename_base)

    # Additional prints
    if prints:
        print(f"\nProcessing complete. Plots saved to: {save_directory}")

def process_files_with_prefixes(load_directory, save_directory, prefixes, duration_minutes=1, prints=False):
    """
    Process all files in the load_directory that start with specific prefixes, and save their plots
    in folders named after the original files with 'plots' appended.

    Parameters:
    load_directory (str): Directory containing the .wav files.
    save_directory (str): Directory to save the plots.
    prefixes (list of str): List of prefixes to filter files.
    duration_minutes (int): Duration to read in minutes for each file.
    prints (bool): Whether to print processing details.
    """
    if not os.path.exists(load_directory):
        raise FileNotFoundError(f"Load directory '{load_directory}' does not exist.")

    for filename in os.listdir(load_directory):
        if filename.endswith('.wav') and any(filename.startswith(prefix) for prefix in prefixes):
            # Full path of the raw audio file
            file_path = os.path.join(load_directory, filename)

            # Save directory for the plots, named after the original file + "plots"
            file_save_directory = os.path.join(save_directory, os.path.splitext(filename)[0] + "_plots")
            # os.path.splitext(filename)[0] returns the filename without the extension, because [0] is the filename and [1] is the extension

            # Process the file
            process_audio_file(file_path, duration_minutes=duration_minutes, save_directory=file_save_directory, prints=prints)

# %%
load_directory = 'data/RAW'
save_directory = 'data/RAW/plots'
prefixes = ['CAFE-', 'STREET-']
# available prefixes: CAFE-, STREET-, HOME-, CAR-
# if the server can't process all of these I will try just 1 at a time

process_files_with_prefixes(load_directory, save_directory, prefixes, duration_minutes=30, prints=True)

# %% [markdown]
# ## Duration of .wav files extraction

# %%
import os
import wave

def get_audio_file_length(file_path):
    """
    Calculate the total length of a .wav audio file in seconds.

    Parameters:
    file_path (str): Path to the .wav file.

    Returns:
    float: Length of the audio file in seconds.
    """
    with wave.open(file_path, 'rb') as wav_file:
        sample_rate = wav_file.getframerate()
        num_frames = wav_file.getnframes()
        duration_sec = num_frames / sample_rate
    return duration_sec

def print_audio_file_lengths(directory):
    """
    Print the total length of all .wav files in a directory.

    Parameters:
    directory (str): Path to the directory containing .wav files.
    """
    if not os.path.exists(directory):
        print(f"Directory '{directory}' does not exist.")
        return

    print(f"Audio File Lengths in Directory: {directory}")
    print("=" * 50)

    for filename in os.listdir(directory):
        if filename.endswith('.wav'):
            file_path = os.path.join(directory, filename)
            try:
                duration_sec = get_audio_file_length(file_path)
                duration_min = duration_sec / 60
                print(f"File: {filename}")
                print(f"  - Length: {duration_sec:.2f} seconds ({duration_min:.2f} minutes)")
            except Exception as e:
                print(f"  - Error processing file {filename}: {e}")


# get the minimum duration of all the files
def get_minimum_audio_file_length(directory):
    """
    Calculate the minimum length of all .wav audio files in a directory.

    Parameters:
    directory (str): Path to the directory containing .wav files.

    Returns:
    float: Minimum length of the audio files in seconds.
    """
    min_duration_sec = float('inf')

    if not os.path.exists(directory):
        print(f"Directory '{directory}' does not exist.")
        return min_duration_sec

    for filename in os.listdir(directory):
        if filename.endswith('.wav'):
            file_path = os.path.join(directory, filename)
            try:
                duration_sec = get_audio_file_length(file_path)
                if duration_sec < min_duration_sec:
                    min_duration_sec = duration_sec
            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    min_duration_min = min_duration_sec / 60
    print(f"\nMinimum Duration of Audio Files: {min_duration_sec:.2f} seconds ({min_duration_min:.2f} minutes)")

# Specify the folder containing the .wav files
folder_path = 'data/RAW'

# Print the lengths of all .wav files in the folder
print_audio_file_lengths(folder_path)
get_minimum_audio_file_length(folder_path)
# Out:
# Audio File Lengths in Directory: data/RAW
# ==================================================
# File: CAR-WINUPB-1_clean.wav
#   - Length: 2111.12 seconds (35.19 minutes)
# File: STREET-CITY-1_clean.wav
#   - Length: 1904.72 seconds (31.75 minutes)
# File: CAFE-FOODCOURTB-2_clean.wav
#   - Length: 1860.00 seconds (31.00 minutes)
# File: CAFE-CAFE-1_clean.wav
#   - Length: 2521.85 seconds (42.03 minutes)
# File: HOME-LIVINGB-1_clean.wav
#   - Length: 2340.00 seconds (39.00 minutes)
# File: CAR-WINDOWNB-1_clean.wav
#   - Length: 2291.11 seconds (38.19 minutes)
# File: STREET-KG-2_clean.wav
#   - Length: 2861.20 seconds (47.69 minutes)
# File: HOME-KITCHEN-2_clean.wav
#   - Length: 3035.47 seconds (50.59 minutes)
# File: CAR-WINDOWNB-2_clean.wav
#   - Length: 2080.03 seconds (34.67 minutes)
# File: HOME-LIVINGB-2_clean.wav
#   - Length: 2340.00 seconds (39.00 minutes)
# File: STREET-KG-1_clean.wav
#   - Length: 3408.18 seconds (56.80 minutes)
# File: HOME-KITCHEN-1_clean.wav
#   - Length: 1979.72 seconds (33.00 minutes)
# File: CAR-WINUPB-2_clean.wav
#   - Length: 2022.11 seconds (33.70 minutes)
# File: CAFE-FOODCOURTB-1_clean.wav
#   - Length: 2040.00 seconds (34.00 minutes)
# File: STREET-CITY-2_clean.wav
#   - Length: 1976.34 seconds (32.94 minutes)
# File: CAFE-CAFE-2_clean.wav
#   - Length: 2362.65 seconds (39.38 minutes)
#
# Minimum Duration of Audio Files: 1860.00 seconds (31.00 minutes)

# %% [markdown]
# ## Resampling from 48 kHz to 16 kHz

# %%
import os
import numpy as np
from scipy.io import wavfile
from scipy.signal import resample_poly

# Specify the directories
load_directory = 'data/RAW'
save_directory = 'data/PROCESSED/16kHz_resampling_zero_clipped'

# Ensure the save directory exists
if not os.path.exists(save_directory):
    os.makedirs(save_directory)

# Define target duration: 31 minutes at 16 kHz
target_minutes = 31
target_sample_rate = 16000
target_duration_seconds = target_minutes * 60
target_length = target_duration_seconds * target_sample_rate  # 31 * 60 * 16000 = 29,760,000 samples

# Process each .wav file in the load directory
for filename in os.listdir(load_directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(load_directory, filename)
        # Read the wav file
        sample_rate, data = wavfile.read(file_path)
        
        # Check if sample rate is 48,000 Hz
        if sample_rate != 48000:
            print(f"File {filename} has sample rate {sample_rate} Hz, expected 48,000 Hz.")
            continue
        
        print(f"Processing {filename}...")

        # Store original data type and get data type info
        original_dtype = data.dtype
        if np.issubdtype(original_dtype, np.integer):
            dtype_info = np.iinfo(original_dtype)
        else:
            dtype_info = np.finfo(original_dtype)

        # Convert data to float64 for processing
        data_float = data.astype(np.float64)

        # Normalize data to -1.0 to 1.0 based on the max possible value for this dtype
        data_norm = data_float / np.abs(dtype_info.max)

        # Resample data from 48,000 Hz to 16,000 Hz
        # If stereo or multi-channel, data has shape (N, C); resample_poly with axis=0 handles all channels simultaneously.
        resampled_data = resample_poly(data_norm, up=1, down=3, axis=0)

        # Clip negative values to zero
        # This operation sets all negative samples to 0, leaving positive values unchanged.
        resampled_data[resampled_data < 0] = 0

        # Scale resampled_data back to original amplitude range
        resampled_data = resampled_data * np.abs(dtype_info.max)

        # Clip the resampled data to the valid range for the data type
        resampled_data = np.clip(resampled_data, dtype_info.min, dtype_info.max)

        # Ensure correct length (31 minutes at 16kHz)
        current_length = resampled_data.shape[0]
        
        # If too long, truncate
        if current_length > target_length:
            resampled_data = resampled_data[:target_length]
        # If too short, pad with zeros
        elif current_length < target_length:
            # Check if mono or multi-channel
            if resampled_data.ndim == 1:
                # Mono
                pad_length = target_length - current_length
                resampled_data = np.pad(resampled_data, (0, pad_length), mode='constant', constant_values=0)
            else:
                # Multi-channel
                pad_length = target_length - current_length
                # Pad along the first dimension (time)
                resampled_data = np.pad(resampled_data, ((0, pad_length), (0,0)), mode='constant', constant_values=0)

        # Convert resampled data to original data type
        resampled_data = resampled_data.astype(original_dtype)

        # Prepare the resampled filename
        resampled_filename = os.path.splitext(filename)[0] + '_16kHz_resampled_zero_clipped.wav'
        resampled_file_path = os.path.join(save_directory, resampled_filename)

        # Save the resampled data
        wavfile.write(resampled_file_path, target_sample_rate, resampled_data)

        print(f"Saved resampled file as {resampled_filename}")
# Out:
# Processing CAR-WINUPB-1_clean.wav...
# Saved resampled file as CAR-WINUPB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-CITY-1_clean.wav...
# Saved resampled file as STREET-CITY-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-FOODCOURTB-2_clean.wav...
# Saved resampled file as CAFE-FOODCOURTB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-CAFE-1_clean.wav...
# Saved resampled file as CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-LIVINGB-1_clean.wav...
# Saved resampled file as HOME-LIVINGB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAR-WINDOWNB-1_clean.wav...
# Saved resampled file as CAR-WINDOWNB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-KG-2_clean.wav...
# Saved resampled file as STREET-KG-2_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-KITCHEN-2_clean.wav...
# Saved resampled file as HOME-KITCHEN-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAR-WINDOWNB-2_clean.wav...
# Saved resampled file as CAR-WINDOWNB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-LIVINGB-2_clean.wav...
# Saved resampled file as HOME-LIVINGB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-KG-1_clean.wav...
# Saved resampled file as STREET-KG-1_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-KITCHEN-1_clean.wav...
# Saved resampled file as HOME-KITCHEN-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAR-WINUPB-2_clean.wav...
# Saved resampled file as CAR-WINUPB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-FOODCOURTB-1_clean.wav...
# Saved resampled file as CAFE-FOODCOURTB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-CITY-2_clean.wav...
# Saved resampled file as STREET-CITY-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-CAFE-2_clean.wav...
# Saved resampled file as CAFE-CAFE-2_clean_16kHz_resampled_zero_clipped.wav

# %%
read_wav('data/PROCESSED/16kHz_resampling/CAR-WINUPB-1_clean_16kHz_resampled.wav', duration_minutes=31, prints=True)
# Out:
# File: CAR-WINUPB-1_clean_16kHz_resampled.wav
# Number of channels: 2
# Sample rate: 16000 Hz
# Sample width: 16 bits
# Number of frames: 33777861
# Frames read: 28800000
# Max samples to read (for 30 minutes): 28800000
# Type of frames: <class 'bytes'>
# Length of frames: 115200000 bytes
# Duration of audio data: 1800.00 seconds (== 30.00 minutes)
# Shape of mono audio data: (28800000,)
# Max value of mono audio data: 16119.5
# Min value of mono audio data: -15156.0
# Average value of mono audio data: -3.9088782291666666
# Peak amplitude: 16119.5
# RMS amplitude: 828.02
# Zero-crossing rate: 347.19 crossings/sec
# (array([  25.5,   59.5,   90. , ..., -194.5, -180. , -191.5]),
#  16000,
#  "File: CAR-WINUPB-1_clean_16kHz_resampled.wav\nNumber of channels: 2\nSample rate: 16000 Hz\nSample width: 16 bits\nNumber of frames: 33777861\nFrames read: 28800000\nMax samples to read (for 30 minutes): 28800000\nType of frames: <class 'bytes'>\nLength of frames: 115200000 bytes\nDuration of audio data: 1800.00 seconds (== 30.00 minutes)\nShape of mono audio data: (28800000,)\nMax value of mono audio data: 16119.5\nMin value of mono audio data: -15156.0\nAverage value of mono audio data: -3.9088782291666666\nPeak amplitude: 16119.5\nRMS amplitude: 828.02\nZero-crossing rate: 347.19 crossings/sec")

# %% [markdown]
# ## Processing .wav file into 1 second .csv files

# %%
import os
import numpy as np
from scipy.io import wavfile

def process_wav_to_csv(file_path, output_folder, start_second=0, stop_second=None):
    """
    Process a .wav file by slicing it into 1-second samples and saving each as a .csv file.

    Parameters:
    - file_path: str, path to the .wav file to process.
    - output_folder: str, path to the folder where .csv files will be saved.
    - start_second: int, starting second from which to begin processing (default is 0).
    - stop_second: int or None, ending second at which to stop processing (default is None, which means process up to 30 minutes).
    """
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Read the .wav file
    sample_rate, data = wavfile.read(file_path)

    # Check if the sample rate is 16 kHz
    if sample_rate != 16000:
        raise ValueError(f"Expected sample rate of 16 kHz, but got {sample_rate} Hz.")

    # Convert stereo to mono if necessary
    if len(data.shape) > 1:
        data = data.mean(axis=1)  # Average the two channels

    # Number of samples per second
    samples_per_second = sample_rate  # 16,000 samples per second

    # Total number of samples in the audio data
    total_samples = data.shape[0]

    # Total number of full seconds in the audio data
    num_seconds_in_file = total_samples // samples_per_second

    # Set default stop_second if not provided
    if stop_second is None:
        stop_second = min(num_seconds_in_file, 30 * 60)  # Limit to the first 30 minutes

    # Ensure start_second and stop_second are within the available data range
    if start_second < 0 or start_second >= num_seconds_in_file:
        raise ValueError(f"start_second ({start_second}) is out of range (0 to {num_seconds_in_file - 1})")
    if stop_second <= start_second or stop_second > num_seconds_in_file:
        raise ValueError(f"stop_second ({stop_second}) must be greater than start_second ({start_second}) and within the available data range.")

    # Get the base file name without extension
    base_file_name = os.path.splitext(os.path.basename(file_path))[0]

    # Process each second of audio in the specified range
    sample_number = 1  # Initialize sample numbering starting from 1
    for second in range(start_second, stop_second):
        start_idx = second * samples_per_second
        end_idx = start_idx + samples_per_second
        sample_data = data[start_idx:end_idx]

        # Save sample_data to .csv file with one column
        csv_file_name = f"{base_file_name}_sample_{sample_number}.csv"
        csv_file_path = os.path.join(output_folder, csv_file_name)

        # Save as .csv with one column
        np.savetxt(csv_file_path, sample_data, delimiter=',')
        print(f"Saved {csv_file_name}")

        sample_number += 1  # Increment sample number

    print("Processing complete.")

# %%
# Specify the file name and directories
file_name = 'CAFE-CAFE-2_clean_16kHz_resampled.wav'  # Replace with your actual .wav file name
input_folder = 'data/PROCESSED/16kHz_resampling'  # Replace with the path to your .wav files
output_folder = 'data/PROCESSED/16kHz_1sec_samples'  # Replace with the path to save .csv files

# Build the full file path
file_path = os.path.join(input_folder, file_name)

# %%
# Process the .wav file
process_wav_to_csv(file_path, output_folder, start_second=0, stop_second=60*30)
# Out:
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_2.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_3.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_4.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_5.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_6.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_7.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_8.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_9.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_10.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_11.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_12.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_13.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_14.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_15.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_16.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_17.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_18.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_19.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_20.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_21.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_22.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_23.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_24.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_25.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_26.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_27.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_28.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_29.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_30.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_31.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_32.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_33.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_34.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_35.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_36.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_37.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_38.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_39.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_40.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_41.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_42.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_43.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_44.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_45.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_46.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_47.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_48.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_49.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_50.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_51.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_52.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_53.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_54.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_55.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_56.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_57.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_58.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_59.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_60.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_61.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_62.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_63.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_64.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_65.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_66.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_67.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_68.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_69.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_70.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_71.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_72.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_73.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_74.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_75.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_76.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_77.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_78.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_79.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_80.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_81.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_82.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_83.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_84.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_85.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_86.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_87.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_88.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_89.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_90.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_91.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_92.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_93.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_94.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_95.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_96.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_97.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_98.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_99.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_100.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_101.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_102.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_103.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_104.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_105.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_106.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_107.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_108.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_109.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_110.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_111.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_112.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_113.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_114.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_115.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_116.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_117.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_118.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_119.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_120.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_121.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_122.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_123.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_124.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_125.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_126.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_127.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_128.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_129.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_130.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_131.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_132.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_133.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_134.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_135.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_136.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_137.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_138.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_139.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_140.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_141.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_142.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_143.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_144.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_145.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_146.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_147.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_148.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_149.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_150.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_151.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_152.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_153.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_154.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_155.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_156.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_157.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_158.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_159.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_160.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_161.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_162.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_163.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_164.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_165.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_166.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_167.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_168.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_169.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_170.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_171.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_172.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_173.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_174.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_175.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_176.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_177.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_178.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_179.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_180.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_181.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_182.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_183.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_184.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_185.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_186.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_187.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_188.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_189.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_190.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_191.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_192.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_193.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_194.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_195.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_196.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_197.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_198.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_199.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_200.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_201.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_202.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_203.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_204.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_205.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_206.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_207.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_208.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_209.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_210.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_211.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_212.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_213.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_214.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_215.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_216.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_217.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_218.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_219.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_220.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_221.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_222.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_223.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_224.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_225.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_226.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_227.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_228.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_229.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_230.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_231.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_232.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_233.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_234.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_235.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_236.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_237.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_238.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_239.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_240.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_241.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_242.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_243.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_244.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_245.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_246.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_247.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_248.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_249.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_250.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_251.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_252.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_253.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_254.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_255.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_256.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_257.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_258.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_259.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_260.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_261.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_262.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_263.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_264.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_265.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_266.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_267.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_268.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_269.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_270.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_271.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_272.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_273.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_274.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_275.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_276.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_277.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_278.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_279.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_280.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_281.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_282.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_283.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_284.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_285.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_286.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_287.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_288.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_289.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_290.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_291.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_292.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_293.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_294.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_295.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_296.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_297.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_298.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_299.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_300.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_301.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_302.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_303.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_304.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_305.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_306.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_307.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_308.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_309.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_310.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_311.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_312.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_313.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_314.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_315.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_316.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_317.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_318.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_319.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_320.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_321.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_322.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_323.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_324.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_325.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_326.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_327.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_328.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_329.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_330.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_331.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_332.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_333.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_334.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_335.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_336.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_337.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_338.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_339.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_340.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_341.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_342.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_343.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_344.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_345.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_346.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_347.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_348.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_349.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_350.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_351.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_352.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_353.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_354.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_355.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_356.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_357.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_358.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_359.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_360.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_361.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_362.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_363.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_364.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_365.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_366.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_367.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_368.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_369.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_370.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_371.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_372.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_373.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_374.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_375.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_376.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_377.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_378.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_379.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_380.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_381.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_382.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_383.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_384.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_385.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_386.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_387.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_388.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_389.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_390.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_391.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_392.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_393.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_394.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_395.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_396.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_397.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_398.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_399.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_400.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_401.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_402.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_403.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_404.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_405.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_406.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_407.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_408.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_409.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_410.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_411.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_412.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_413.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_414.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_415.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_416.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_417.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_418.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_419.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_420.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_421.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_422.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_423.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_424.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_425.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_426.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_427.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_428.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_429.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_430.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_431.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_432.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_433.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_434.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_435.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_436.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_437.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_438.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_439.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_440.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_441.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_442.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_443.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_444.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_445.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_446.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_447.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_448.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_449.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_450.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_451.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_452.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_453.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_454.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_455.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_456.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_457.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_458.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_459.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_460.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_461.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_462.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_463.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_464.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_465.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_466.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_467.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_468.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_469.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_470.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_471.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_472.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_473.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_474.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_475.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_476.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_477.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_478.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_479.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_480.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_481.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_482.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_483.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_484.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_485.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_486.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_487.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_488.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_489.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_490.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_491.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_492.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_493.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_494.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_495.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_496.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_497.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_498.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_499.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_500.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_501.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_502.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_503.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_504.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_505.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_506.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_507.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_508.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_509.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_510.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_511.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_512.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_513.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_514.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_515.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_516.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_517.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_518.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_519.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_520.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_521.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_522.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_523.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_524.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_525.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_526.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_527.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_528.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_529.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_530.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_531.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_532.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_533.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_534.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_535.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_536.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_537.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_538.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_539.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_540.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_541.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_542.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_543.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_544.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_545.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_546.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_547.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_548.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_549.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_550.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_551.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_552.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_553.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_554.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_555.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_556.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_557.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_558.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_559.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_560.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_561.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_562.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_563.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_564.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_565.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_566.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_567.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_568.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_569.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_570.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_571.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_572.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_573.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_574.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_575.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_576.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_577.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_578.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_579.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_580.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_581.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_582.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_583.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_584.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_585.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_586.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_587.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_588.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_589.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_590.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_591.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_592.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_593.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_594.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_595.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_596.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_597.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_598.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_599.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_600.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_601.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_602.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_603.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_604.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_605.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_606.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_607.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_608.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_609.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_610.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_611.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_612.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_613.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_614.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_615.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_616.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_617.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_618.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_619.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_620.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_621.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_622.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_623.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_624.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_625.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_626.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_627.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_628.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_629.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_630.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_631.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_632.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_633.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_634.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_635.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_636.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_637.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_638.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_639.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_640.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_641.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_642.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_643.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_644.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_645.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_646.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_647.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_648.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_649.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_650.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_651.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_652.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_653.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_654.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_655.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_656.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_657.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_658.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_659.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_660.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_661.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_662.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_663.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_664.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_665.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_666.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_667.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_668.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_669.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_670.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_671.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_672.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_673.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_674.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_675.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_676.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_677.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_678.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_679.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_680.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_681.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_682.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_683.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_684.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_685.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_686.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_687.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_688.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_689.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_690.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_691.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_692.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_693.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_694.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_695.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_696.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_697.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_698.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_699.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_700.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_701.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_702.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_703.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_704.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_705.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_706.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_707.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_708.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_709.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_710.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_711.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_712.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_713.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_714.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_715.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_716.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_717.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_718.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_719.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_720.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_721.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_722.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_723.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_724.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_725.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_726.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_727.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_728.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_729.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_730.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_731.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_732.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_733.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_734.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_735.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_736.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_737.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_738.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_739.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_740.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_741.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_742.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_743.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_744.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_745.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_746.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_747.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_748.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_749.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_750.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_751.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_752.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_753.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_754.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_755.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_756.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_757.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_758.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_759.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_760.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_761.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_762.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_763.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_764.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_765.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_766.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_767.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_768.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_769.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_770.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_771.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_772.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_773.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_774.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_775.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_776.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_777.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_778.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_779.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_780.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_781.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_782.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_783.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_784.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_785.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_786.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_787.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_788.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_789.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_790.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_791.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_792.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_793.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_794.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_795.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_796.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_797.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_798.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_799.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_800.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_801.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_802.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_803.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_804.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_805.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_806.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_807.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_808.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_809.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_810.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_811.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_812.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_813.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_814.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_815.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_816.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_817.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_818.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_819.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_820.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_821.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_822.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_823.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_824.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_825.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_826.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_827.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_828.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_829.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_830.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_831.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_832.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_833.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_834.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_835.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_836.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_837.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_838.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_839.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_840.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_841.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_842.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_843.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_844.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_845.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_846.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_847.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_848.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_849.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_850.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_851.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_852.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_853.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_854.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_855.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_856.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_857.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_858.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_859.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_860.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_861.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_862.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_863.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_864.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_865.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_866.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_867.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_868.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_869.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_870.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_871.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_872.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_873.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_874.csv
# ...
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1516.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1517.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1518.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1519.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1520.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1521.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1522.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1523.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1524.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1525.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1526.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1527.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1528.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1529.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1530.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1531.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1532.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1533.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1534.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1535.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1536.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1537.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1538.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1539.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1540.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1541.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1542.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1543.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1544.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1545.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1546.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1547.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1548.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1549.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1550.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1551.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1552.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1553.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1554.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1555.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1556.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1557.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1558.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1559.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1560.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1561.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1562.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1563.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1564.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1565.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1566.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1567.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1568.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1569.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1570.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1571.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1572.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1573.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1574.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1575.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1576.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1577.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1578.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1579.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1580.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1581.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1582.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1583.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1584.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1585.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1586.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1587.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1588.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1589.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1590.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1591.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1592.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1593.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1594.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1595.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1596.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1597.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1598.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1599.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1600.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1601.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1602.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1603.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1604.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1605.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1606.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1607.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1608.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1609.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1610.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1611.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1612.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1613.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1614.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1615.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1616.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1617.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1618.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1619.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1620.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1621.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1622.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1623.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1624.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1625.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1626.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1627.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1628.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1629.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1630.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1631.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1632.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1633.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1634.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1635.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1636.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1637.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1638.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1639.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1640.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1641.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1642.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1643.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1644.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1645.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1646.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1647.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1648.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1649.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1650.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1651.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1652.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1653.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1654.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1655.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1656.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1657.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1658.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1659.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1660.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1661.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1662.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1663.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1664.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1665.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1666.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1667.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1668.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1669.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1670.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1671.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1672.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1673.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1674.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1675.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1676.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1677.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1678.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1679.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1680.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1681.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1682.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1683.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1684.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1685.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1686.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1687.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1688.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1689.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1690.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1691.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1692.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1693.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1694.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1695.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1696.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1697.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1698.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1699.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1700.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1701.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1702.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1703.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1704.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1705.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1706.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1707.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1708.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1709.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1710.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1711.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1712.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1713.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1714.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1715.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1716.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1717.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1718.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1719.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1720.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1721.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1722.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1723.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1724.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1725.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1726.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1727.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1728.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1729.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1730.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1731.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1732.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1733.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1734.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1735.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1736.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1737.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1738.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1739.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1740.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1741.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1742.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1743.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1744.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1745.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1746.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1747.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1748.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1749.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1750.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1751.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1752.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1753.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1754.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1755.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1756.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1757.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1758.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1759.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1760.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1761.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1762.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1763.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1764.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1765.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1766.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1767.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1768.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1769.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1770.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1771.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1772.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1773.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1774.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1775.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1776.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1777.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1778.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1779.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1780.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1781.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1782.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1783.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1784.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1785.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1786.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1787.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1788.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1789.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1790.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1791.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1792.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1793.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1794.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1795.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1796.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1797.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1798.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1799.csv
# Saved CAFE-CAFE-2_clean_16kHz_resampled_sample_1800.csv
# Processing complete.

# %% [markdown]
# ## Dividing original .wav files into 24min for train and validation + 6min for test datasets

# %%
import os
import numpy as np
from scipy.io import wavfile

# Directories
source_directory = 'data/PROCESSED/16kHz_resampling_zero_clipped'
train_val_directory = 'data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset'
test_directory = 'data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset'

# Create output directories if they don't exist
os.makedirs(train_val_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

# Define durations
# 16 kHz sampling rate
sample_rate = 16000
minutes_24 = 24 * 60  # seconds in 24 minutes
minutes_6 = 6 * 60    # seconds in 6 minutes
separation = 1 * 60  # 1 minute separation between train/val and test data

num_samples_24_min = minutes_24 * sample_rate
num_samples_6_min = minutes_6 * sample_rate
num_samples_sep = separation * sample_rate

# Process each .wav file in the source directory
for filename in os.listdir(source_directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(source_directory, filename)

        # Read the wav file
        sr, data = wavfile.read(file_path)

        # Check if the sampling rate is 16 kHz
        if sr != sample_rate:
            print(f"File {filename} has sample rate {sr} Hz, expected 16,000 Hz.")
            continue

        print(f"Processing {filename}...")

        # Check length of the file
        total_samples = data.shape[0]

        # Ensure file is at least 31 minutes long: 24 + 6 + 1 = 31 min total
        required_length = num_samples_24_min + num_samples_6_min + num_samples_sep
        if total_samples < required_length:
            print(f"File {filename} is shorter than 31 minutes. Total samples: {total_samples}, needed {required_length}. Skipping.")
            continue

        # Extract first 24 minutes
        train_val_data = data[:num_samples_24_min]

        # Extract last 6 minutes
        test_data = data[-num_samples_6_min:]

        # Save the first 24 minutes to train_val_directory with the same filename
        train_val_filepath = os.path.join(train_val_directory, filename)
        wavfile.write(train_val_filepath, sample_rate, train_val_data)

        # Save the last 6 minutes to test_directory with the same filename
        test_filepath = os.path.join(test_directory, filename)
        wavfile.write(test_filepath, sample_rate, test_data)

        print(f"Saved first 24-minute part to {train_val_filepath}")
        print(f"Saved last 6-minute part to {test_filepath}")
# Out:
# Processing CAR-WINUPB-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAR-WINUPB-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAR-WINUPB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-KG-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/STREET-KG-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/STREET-KG-2_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-CITY-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/STREET-CITY-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/STREET-CITY-2_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-CITY-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/STREET-CITY-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/STREET-CITY-1_clean_16kHz_resampled_zero_clipped.wav
# Processing STREET-KG-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/STREET-KG-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/STREET-KG-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAR-WINUPB-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAR-WINUPB-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAR-WINUPB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAR-WINDOWNB-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAR-WINDOWNB-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAR-WINDOWNB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-KITCHEN-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/HOME-KITCHEN-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/HOME-KITCHEN-1_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-KITCHEN-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/HOME-KITCHEN-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/HOME-KITCHEN-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAR-WINDOWNB-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAR-WINDOWNB-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAR-WINDOWNB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-LIVINGB-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/HOME-LIVINGB-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/HOME-LIVINGB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing HOME-LIVINGB-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/HOME-LIVINGB-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/HOME-LIVINGB-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-FOODCOURTB-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAFE-FOODCOURTB-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAFE-FOODCOURTB-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-CAFE-2_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAFE-CAFE-2_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAFE-CAFE-2_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAFE-CAFE-1_clean_16kHz_resampled_zero_clipped.wav
# Processing CAFE-FOODCOURTB-1_clean_16kHz_resampled_zero_clipped.wav...
# Saved first 24-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_train_val_dataset/CAFE-FOODCOURTB-1_clean_16kHz_resampled_zero_clipped.wav
# Saved last 6-minute part to data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/CAFE-FOODCOURTB-1_clean_16kHz_resampled_zero_clipped.wav

# %% [markdown]
# ## Separating .wav files into 1 second .csv files (for training / validation) or 1 minute (for test)

# %%
import os
import numpy as np
from scipy.io import wavfile
import csv

# Input .wav file
input_wav_file = 'data/PROCESSED/16kHz_resampling_zero_clipped/wav_test_dataset/STREET-KG-2_clean_16kHz_resampled_zero_clipped.wav'
output_directory = 'data/PROCESSED/1sec_TEST_dataset/STREET'

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Read the WAV file
sample_rate, data = wavfile.read(input_wav_file)

# Check that the sample rate is 16 kHz
expected_sample_rate = 16000
if sample_rate != expected_sample_rate:
    raise ValueError(f"Expected sample rate {expected_sample_rate} Hz, got {sample_rate} Hz")

# Convert stereo to mono if necessary
if data.ndim > 1:
    data = data.mean(axis=1)

total_samples = data.shape[0]

# Number of samples per segment 
samples_per_segment = sample_rate * 60 # 1 minute segments
num_segments = total_samples // samples_per_segment

# Get the base name of the input file (without extension)
base_name = os.path.splitext(os.path.basename(input_wav_file))[0]

for i in range(num_segments):
    # Segment start and end indices
    start_idx = i * samples_per_segment
    end_idx = start_idx + samples_per_segment
    
    segment_data = data[start_idx:end_idx]
    
    # Prepare output CSV file name
    # Segment numbers start from 1 for readability
    segment_number = i + 1
    output_csv_filename = f"{base_name}_segment_{segment_number}.csv"
    output_csv_path = os.path.join(output_directory, output_csv_filename)
    
    # Save segment_data to CSV, one column
    # Each row in the CSV will contain a single sample value.
    with open(output_csv_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        for sample_value in segment_data:
            writer.writerow([sample_value])
    
    print(f"Saved segment {segment_number} to {output_csv_path}")

# If there is a remainder (file length not a multiple of 1 second), you can handle it here:
remainder = total_samples % samples_per_segment
if remainder > 0:
    # Decide what to do:
    # Option 1: Skip the leftover samples
    # Option 2: Save them as a shorter last segment
    # Here we choose to save them as a shorter segment:
    start_idx = num_segments * samples_per_segment
    remainder_data = data[start_idx:]
    segment_number = num_segments + 1
    output_csv_filename = f"{base_name}_segment_{segment_number}.csv"
    output_csv_path = os.path.join(output_directory, output_csv_filename)
    
    with open(output_csv_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        for sample_value in remainder_data:
            writer.writerow([sample_value])
    
    print(f"Saved remainder segment {segment_number} (shorter) to {output_csv_path}")
# Out:
# Saved segment 1 to data/PROCESSED/1sec_TEST_dataset/STREET/STREET-KG-2_clean_16kHz_resampled_zero_clipped_segment_1.csv
# Saved segment 2 to data/PROCESSED/1sec_TEST_dataset/STREET/STREET-KG-2_clean_16kHz_resampled_zero_clipped_segment_2.csv
# Saved segment 3 to data/PROCESSED/1sec_TEST_dataset/STREET/STREET-KG-2_clean_16kHz_resampled_zero_clipped_segment_3.csv
# Saved segment 4 to data/PROCESSED/1sec_TEST_dataset/STREET/STREET-KG-2_clean_16kHz_resampled_zero_clipped_segment_4.csv
# Saved segment 5 to data/PROCESSED/1sec_TEST_dataset/STREET/STREET-KG-2_clean_16kHz_resampled_zero_clipped_segment_5.csv
# Saved segment 6 to data/PROCESSED/1sec_TEST_dataset/STREET/STREET-KG-2_clean_16kHz_resampled_zero_clipped_segment_6.csv
